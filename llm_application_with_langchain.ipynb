# %% [markdown]
# # Building a Trip Planner Application with LangChain
#
# Build a simple trip planner using LangChain. The app takes a destination and a few preferences, then outputs a tailored trip plan. We'll use the LangChain Expression Language (LCEL) to chain together components such as prompt templates and LLMs.

# %% [markdown]
# ### Imports
# We start by importing the necessary libraries:

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os

from dotenv import load_dotenv
_ = load_dotenv()

# %% [markdown]
# ### Define the Language Model
# We'll use GPT-4 to process user input and generate trip plans.

# %%
model = ChatOpenAI(
    model="openai/gpt-oss-120b:free",  
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY")
)

# %% [markdown]
# ### Define Prompt Template
# We use a prompt template to set the context for the LLM to generate personalized trip plans based on user input.

# %%
system_template = """
You are a trip planner expert. Help me plan a trip to {destination}.
Consider my preferences for {preferences}.
"""

prompt_template = ChatPromptTemplate.from_messages([
    ('system', system_template),
    ('user', 'What should I do in {destination}?')
])

# %% [markdown]
# ### Output Parsing
# We use a simple output parser to extract the LLM's response as a string.

# %%
parser = StrOutputParser()

# %% [markdown]
# ### Chain Components Together
# We now chain the prompt template, model, and output parser to process input and output.

# %%
trip_planner_chain = prompt_template | model | parser

# %% [markdown]
# ### Query the Model
# We define a function to run a query through the trip planner.

# %%
def plan_trip(destination, preferences):
    input_data = {"destination": destination, "preferences": preferences}
    return trip_planner_chain.invoke(input_data)

# %%
# helper function to render markdown
from IPython.display import Markdown, display

def render_markdown(md_string):
    display(Markdown(md_string))

# %% [markdown]
# ### Running the Trip Planner
# Now, let's run the trip planner with different inputs:

# %%
result = plan_trip("Paris", "museums, cafes, historical sites")
render_markdown(result)
# Out:
# ## Paris in a Nutshell – A “Museums + Cafés + History” Playbook
#
# Below is a **ready‑to‑use, flexible itinerary** (4‑day version, but you can stretch or shrink it) that strings together the city’s top museums, iconic cafés, and must‑see historic sites while leaving room for wandering, food‑stops, and a few off‑the‑beaten‑path gems.
#
# ---
#
# ### QUICK‑LOOK OVERVIEW
#
# | Day | Morning (Museums) | Mid‑day (Café & Lunch) | Afternoon (Historic Sites) | Evening (Culture/Relax) |
# |-----|-------------------|------------------------|----------------------------|--------------------------|
# | **1** | **Louvre** (Denon & Sully wings) | Café **Marcel** (near Palais‑Royal) – croissant & café au lait | **Palais‑Royal** gardens → **Île de la Cité** (Notre‑Dame façade, Sainte‑Chapelle) | Seine sunset cruise + dinner in **Le Marais** |
# | **2** | **Musée d’Orsay** (Impressionists) | **Café de Flore** (Saint‑Germain) – classic Parisian brunch | **Saint‑Germain‑des‑Prés** & **Luxembourg Gardens** (historic church, Medici tombs) | Jazz at **Le Caveau de la Huchette** |
# | **3** | **Centre Pompidou** (Modern art) | **Café Kitsuné** (Le Marais) – matcha latte & almond croissant | **Le Marais** walking tour (Place des Vosges, Hôtel de Ville, Musée Carnavalet) | Dinner at **Chez Janou** + night‑cap at **Bar Hemingway** |
# | **4** | **Musée Rodin** (sculpture garden) | **Café Loustic** (7ᵗʰ arr.) – pistachio pastry | **Les Invalides** (Napoleon’s tomb) → **Eiffel Tower** (Champ de Mars) | Light show at the Tower + late‑night stroll on the **Seine** |
#
# *If you have more days, add:*
#
# - **Day 5:** **Versailles** (palace & gardens) – lunch at **La Petite Venise** in the park.
# - **Day 6:** **Musée Marmottan Monet** + **Giverny** (Monet’s house & gardens).
#
# ---
#
# ## 1️⃣ DAY‑BY‑DAY DEEP DIVE
#
# ### Day 1 – “The Classic First Impression”
#
# | Time | Activity | Why It Fits Your Interests |
# |------|----------|----------------------------|
# | **9:00 – 12:30** | **Louvre** – focus on Denon (Italian Renaissance, Greek antiquities) & Sully (Egyptian & Near Eastern). Skip the crowded Denon “Mona Lisa” line by pre‑booking a timed ticket and heading straight to **Salle des États**. | World‑class museum, art history depth, iconic works. |
# | **12:45 – 13:45** | **Café Marcel** (Palais‑Royal) – buttery croissant, café crème, and a glass of fresh orange juice. Sit on the terrace overlooking the **Colonnes de Buren**. | Classic Parisian café vibe, perfect for people‑watching. |
# | **14:00 – 16:30** | **Île de la Cité**: Walk to **Notre‑Dame** (exterior, crypt) → **Sainte‑Chapelle** (stained‑glass marvel). End at **Conciergerie** (Marie‑Antoinette’s prison). | Concentrated medieval history, stunning architecture. |
# | **17:00 – 19:00** | **Seine Cruise** (Bateaux‑Mouches) – depart near Pont Neuf. Choose the “dîner‑cruise” if you’re hungry, otherwise a 1‑hour sunset ride. | Romantic view of monuments lit up; a gentle way to rest after walking. |
# | **19:30 – 21:30** | Dinner in **Le Marais** – try **L’As du Fallafel** (quick, legendary) or **Chez Janou** (Provençal). | Le Marais is historic, lively, and full of cafés for a nightcap. |
#
# **Tips**
# - **Ticket hack:** Buy a **Paris Museum Pass** (2‑day or 4‑day) for skip‑the‑line entry to Louvre, Orsay, Centre Pompidou, Rodin, etc.
# - **Metro:** Use line 1 (Palais‑Royal – Musée du Louvre) and line 4 (Cité). Get a **Navigo Découverte** weekly pass (€22.80 + €5 for the card) – unlimited rides.
#
# ---
#
# ### Day 2 – “Impressionist & Literary Paris”
#
# | Time | Activity | Highlights |
# |------|----------|------------|
# | **9:00 – 12:00** | **Musée d’Orsay** – start with Monet’s “Water Lilies”, then Degas, Renoir, Van Gogh. The clock face on the top floor offers a panoramic view. | Impressionist masterpieces in a former railway station. |
# | **12:30 – 14:00** | **Café de Flore** (Saint‑Germain) – order the “café au lait” and a **pain au chocolat**. Sit on the historic terrace where Sartre & Simone de Beauvoir once debated. | Legendary literary café, perfect for a leisurely lunch. |
# | **14:30 – 17:00** | **Saint‑Germain‑des‑Prés** (oldest church on the Left Bank) → **Luxembourg Gardens** (medieval Medici tomb, French‑style garden). | Blend of religious history and elegant green space. |
# | **18:00 – 20:30** | **Jazz Club** – **Le Caveau de la Huchette** (5ᵗʰ arr.) – classic swing & bebop in a 16ᵗʰ‑century cellar. | Night‑time cultural immersion, live music. |
# | **21:00** | Late‑night bite: **L’Avant Comptoir** (small plates, great charcuterie). | Perfect for a quick, tasty stop before heading back. |
#
# **Tips**
# - **Orsay ticket** includes the **Orsay & Orangerie** combo; you can pop into the **Orangerie** (Monet’s “Water Lilies” rooms) later if you have time.
# - **Café etiquette:** Order at the counter, then find a seat. Tipping is optional (5‑10 % if service is exceptional).
#
# ---
#
# ### Day 3 – “Modern Art & Marais Wanderings”
#
# | Time | Activity | Why It’s a Must |
# |------|----------|-----------------|
# | **9:30 – 12:30** | **Centre Pompidou** – explore the **Musée National d’Art Moderne** (Picasso, Kandinsky, Duchamp). Take the escalator to the **Terrasse** for a 360° view of Paris. | Cutting‑edge art, interactive displays, great city vista. |
# | **13:00 – 14:30** | **Café Kitsuné** (Le Marais) – matcha latte, almond croissant, and a side of “Kitsuné” music playlist. | Hip, design‑forward spot that bridges fashion & coffee culture. |
# | **15:00 – 18:00** | **Le Marais Walking Tour** – **Place des Vosges**, **Musée Carnavalet** (history of Paris), **Hôtel de Ville**, **Rue des Rosiers** (Jewish quarter). Stop at **Merci** concept store for a coffee break. | Historic neighborhoods, boutique shopping, and hidden courtyards. |
# | **19:30 – 22:00** | Dinner at **Chez Janou** (Provençal, great pastis) → **Bar Hemingway** (Ritz) for a classic cocktail. | End the day with a touch of old‑world glamour. |
#
# **Tips**
# - **Pompidou** can be overwhelming; pick 2–3 floors you’re most interested in and skip the rest.
# - **Le Marais** is best explored on foot; wear comfortable shoes.
#
# ---
#
# ### Day 4 – “Sculpture, Military History & the Eiffel Tower”
#
# | Time | Activity | Highlights |
# |------|----------|------------|
# | **9:00 – 11:30** | **Musée Rodin** – see “The Thinker”, “The Gates of Hell”, and the beautiful **Méditation Garden**. | Outdoor sculpture garden perfect for a relaxed morning. |
# | **12:00 – 13:30** | **Café Loustic** (7ᵗʰ arr.) – pistachio‑rose pastry, espresso. | Small, stylish spot with excellent pastries. |
# | **14:00 – 16:30** | **Les Invalides** – Napoleon’s tomb, **Musée de l’Armée** (armor, swords, WWII exhibits). | Deep dive into French military history. |
# | **17:00 – 19:00** | **Eiffel Tower** – pre‑book a **2nd‑floor** ticket (skip the summit line). Walk the **Champ de Mars** at golden hour. | Iconic landmark, photo‑ops, and a chance to relax on the lawns. |
# | **20:00 – 22:00** | **Light Show** (hourly after sunset) + dinner at **Le Jules Verne** (if you splurge) or **Café Constant** (more casual). | End with the tower’s sparkling illumination. |
#
# **Tips**
# - **Rodin** tickets are free on the first Sunday of each month (if you’re traveling in spring).
# - **Eiffel Tower**: Arrive 30 min before your slot; the line for the elevators can still be long.
#
# ---
#
# ## 2️⃣ MUST‑SEE MUSEUMS (Beyond the Core Four)
#
# | Museum | Specialty | How Much Time? | Insider Tip |
# |--------|-----------|----------------|-------------|
# | **Musée de l’Orangerie** | Monet’s “Water Lilies” & Impressionist works | 1 h | Combine with a quick walk from the **Tuileries**. |
# | **Musée Jacquemart‑André** | 19ᵗʰ‑century mansion, fine art & decorative objects | 1 h | Café inside serves a **chocolate mousse** worth the detour. |
# | **Musée Marmottan Monet** (16ᵗʰ arr.) | Largest Monet collection, **“Impression, Sunrise”** | 2 h | Less crowded; perfect for a quiet afternoon. |
# | **Musée Picasso** (Marais) | Over 5,000 works, sketches, ceramics | 1.5 h | Free first Saturday of each month (Oct‑Mar). |
# | **Musée du Quai Branly – Jacques Chirac** | Non‑European art, tribal masks, immersive installations | 1.5 h | Rooftop view of the Eiffel Tower at sunset. |
#
# ---
#
# ## 3️⃣ CAFÉ CULTURE – WHERE TO SIP & PEOPLE‑WATCH
#
# | Café | Neighborhood | Signature | Best Time to Go |
# |------|--------------|-----------|-----------------|
# | **Café de Flore** | Saint‑Germain | Café au lait + croissant | Early morning (before 9 am) to avoid crowds |
# | **Les Deux Magots** | Saint‑Germain | Hot chocolate | Mid‑afternoon for a quiet vibe |
# | **Café Kitsuné** | Le Marais | Matcha latte | Late morning, perfect for Instagram |
# | **Café Loustic** | 7ᵗʰ arr. | Pistachio‑rose pastry | After museum visits (Rodin, Orsay) |
# | **Café Marly** (Louvre) | Louvre Courtyard | View of the Pyramid | Lunch (reserve a table) |
# | **La Caféothèque** | 4ᵗʰ arr. | Single‑origin pour‑over | Coffee‑geek afternoon (they host tastings) |
# | **Le Peloton Café** | Canal Saint‑Martin | Espresso tonic | Evening, after a stroll along the canal |
#
# ---
#
# ## 4️⃣ HISTORIC SITES – QUICK‑LOOK GUIDE
#
# | Site | Era | Must‑See Detail | Proximity to Metro |
# |------|-----|----------------|--------------------|
# | **Notre‑Dame** (Île de la Cité) | Gothic (12ᵗʰ c) | Rose window, gargoyles | Cité (Line 4) |
# | **Sainte‑Chapelle** | 13ᵗʰ c | 15 × 15 m of stained glass | Cité |
# | **Conciergerie** | Medieval prison | Marie‑Antoinette’s cell | Cité |
# | **Palais‑Royal** | 17ᵗʰ c | Colonnes de Buren, garden | Palais‑Royal – Musée du Louvre (Line 1) |
# | **Hôtel de Ville** | Renaissance | Grand façade, interior murals | Hôtel de Ville (Line 1, 11) |
# | **Place des Vosges** | 17ᵗʰ c | Symmetrical red‑brick houses | Saint‑Paul (Line 1) |
# | **Les Invalides** | 17ᵗʰ c | Napoleon’s tomb, military museum | Invalides (Line 13, RER C) |
# | **Versailles Palace** | 17ᵗʰ c | Hall of Mirrors, fountains | RER C (Versailles‑Rive Gauche) |
# | **Arc de Triomphe** | 19ᵗʰ c | View from top (12 km panorama) | Charles de Gaulle – Étoile (Line 1, 2, 6) |
# | **Père Lachaise Cemetery** | 19ᵗʰ c | Graves of Jim Morrison, Oscar Wilde | Pelleport (Line 3) |
#
# ---
#
# ## 5️⃣ DAY‑TRIPS (If You Have Extra Time)
#
# | Destination | Travel Time | Highlights | Suggested Lunch |
# |-------------|-------------|------------|-----------------|
# | **Versailles** | 30 min RER C | Palace, Gardens, Trianon, Musical Fountain Shows (summer) | **La Petite Venise** (Italian‑style in the gardens) |
# | **Giverny** | 45 min train (Vernon) + 15 min bus | Monet’s house, water‑lily garden, Japanese bridge | **Le Jardin des Plumes** (farm‑to‑table) |
# | **Chartres** | 1 h train (direct) | Chartres Cathedral (UNESCO, stained glass) | **Le Petit Café** (classic French bistro) |
# | **Provins** (medieval walled town) | 1 h 15 min train | Ramparts, “La Tête en l’air” shows, medieval market | **Le Relais de la Place** (regional specialties) |
# | **Reims** (Champagne) | 45 min TGV | Notre‑Dame de Reims, champagne house tours (Veuve Clicquot) | **Café du Palais** (crème brûlée) |
#
# ---
#
# ## 6️⃣ PRACTICAL INFO & QUICK HACKS
#
# | Topic | Details |
# |-------|---------|
# | **Transport** | - **Navigo Découverte** weekly pass (€22.80 + €5 card) = unlimited Metro, RER, bus, tram. <br>- **RER** for Versailles, Giverny, Orly/Charles‑de‑Gaulle airports. |
# | **Museum Pass** | 2‑day pass (€53) covers Louvre, Orsay, Centre Pompidou, Rodin, Musée de l’Orangerie, and more. Great if you plan 3+ museums. |
# | **Wi‑Fi** | Free city‑wide Wi‑Fi in most cafés, libraries, and the **Paris Wi‑Fi** municipal network. |
# | **Language** | French is the default; most staff in museums speak English. A few polite French phrases go a long way: “Bonjour”, “Merci”, “S’il vous plaît”. |
# | **Safety** | Pickpockets in crowded areas (Metro, tourist sites). Keep wallet in front pocket, use a money belt, and be wary of “helpful” strangers. |
# | **Dining Etiquette** | Lunch (12‑2 pm) and dinner (7‑10 pm) are the main meals. Many cafés close between 3‑5 pm; plan accordingly. |
# | **Cash vs Card** | Card (Visa/MasterCard) accepted everywhere; keep a small amount of euros for markets or small cafés. |
# | **Weather** | December‑February: 3‑7 °C, rain possible. Dress in layers, waterproof shoes, and a scarf. Summer (June‑August): 20‑25 °C, occasional heatwave. Light clothing +

# %%
result = plan_trip("Tokyo", "technology, culture, nightlife")
render_markdown(result)
# Out:
# ## Tokyo in a Nutshell
# Tokyo is a city that lives on three different frequencies at once – **cutting‑edge tech**, **deep‑rooted culture**, and **electric nightlife**. Below is a curated guide that lets you flip between those frequencies at will, with a flexible 5‑day itinerary, practical tips, and a menu of “must‑do” experiences for each of your interests.
#
# ---
#
# ## 1️⃣ QUICK‑LOOK: TOP 3‑FOR‑YOU LIST
#
# | Tech‑Heavy | Culture‑Rich | Nightlife‑Hotspots |
# |------------|--------------|--------------------|
# | **Akihabara** – electronics megastore, retro‑gaming arcades, maid cafés | **Asakusa & Senso‑ji** – historic temple, Nakamise‑dori market | **Golden Golden (Golden Gai)** – tiny bars, Shinjuku |
# | **teamLab Borderless / Planets** (Odaiba) – immersive digital art | **Meiji Shrine** – forested shrine in Harajuku | **Shibuya Scramble Crossing** – rooftop bars, clubs |
# | **Miraikan (National Museum of Emerging Science & Innovation)** – robots, AI demos | **Edo‑Tokyo Museum** – city’s samurai‑era story | **Roppongi Hills / Mori Tower** – upscale clubs, art‑bar mix |
# | **VR & AR arcades** (Shinjuku, Shibuya) – “real‑world gaming” | **Tsukiji Outer Market** – food culture, sushi‑making class | **Shinjuku Kabukicho** – neon‑lit streets, karaoke |
# | **Robot Restaurant** (Shinjuku) – high‑tech cabaret | **Ghibli Museum** (Mitaka) – animation heritage (tickets required) | **Womb (Shibuya)** – world‑class techno/house club |
#
# ---
#
# ## 2️⃣ 5‑DAY SAMPLE ITINERARY
# *(Adjust day‑counts or swap activities based on your arrival/departure times.)*
#
# ### Day 1 – Arrival & First Tech Immersion
# **Morning** – Land at Haneda or Narita → Grab a **Suica/Pasmo** prepaid card (or Apple Wallet “Transit Card”) at the airport.
# **Afternoon** – **Odaiba**
# *   **teamLab Borderless** (or **teamLab Planets** if you prefer the water‑walk experience).
# *   Walk the **Palette Town** shopping complex, pop into **Toyota Mega Web** for future‑car demos.
# **Evening** – **Roppongi**
# *   Dinner at **Ishikawa** (Michelin‑starred kaiseki) for a cultural palate.
# *   Head up to **Mori Tower Sky Deck** for night‑city views, then drop into **Roppongi Nightclub** (e.g., **V2 Tokyo**) for a high‑energy start.
#
# ### Day 2 – Akihabara & Traditional Heart
# **Morning** – **Akihabara**
# *   Browse **Yodobashi Camera** (10‑floor tech heaven).
# *   Visit **Mandarake** for retro manga & collectibles.
# *   Try a **Maid Café** (e.g., @Home Café) for a quirky pop‑culture bite.
# **Afternoon** – **Asakusa**
# *   Walk through **Nakamise‑dori** (street‑food stalls).
# *   Explore **Senso‑ji** temple; rent a kimono for photos.
# *   Optional: **Sumida River cruise** to see the skyline from water.
# **Evening** – **Shinjuku**
# *   Dinner at **Omoide Yokocho** (tiny yakitori stalls).
# *   **Robot Restaurant** (or **VR Zone Shinjuku** for a more interactive show).
# *   End at **Golden Gai** – hop between 2‑seat bars; each has its own vibe.
#
# ### Day 3 – Culture Deep‑Dive & Night‑Tech
# **Morning** – **Meiji Shrine** & **Harajuku**
# *   Stroll the forested path to the shrine, then people‑watch on **Takeshita‑Street** (fashion tech meets street art).
# **Afternoon** – **Omotesando & Aoyama**
# *   Visit **Omotesando Hills** for design‑forward boutiques (Apple Store, Dior, etc.).
# *   Check out **Mori Art Museum** (Roppongi) or **Nezu Museum** (traditional garden + modern art).
# **Evening** – **Shibuya**
# *   Grab a **ramen** bowl at **Ichiran** (solo‑dining booths).
# *   Experience the **Shibuya Scramble Crossing** from the **Starbucks** on the 8th floor.
# *   Nightclub **Womb** (tech‑heavy lighting, world‑renowned DJs) or **Contact** for underground beats.
#
# ### Day 4 – Future‑Tech Playground & Night Market
# **Morning** – **Miraikan (National Museum of Emerging Science & Innovation)** – see ASIMO robot, interactive AI exhibits.
# **Afternoon** – **Tokyo Bay**
# *   Ride the **Yurikamome Line** to **Odaiba** again for **DiverCity** (giant Gundam statue).
# *   Try **VR Zone** at **Joypolis** (arcade meets virtual reality).
# **Evening** – **Ebisu/Yebisu Garden Place**
# *   Dinner at **Yebisu Beer Museum** (brewery tour + craft beer).
# *   Walk to **Ebisu Yokocho** – a narrow alley of izakayas, perfect for a low‑key night.
#
# ### Day 5 – Day‑Trip + Farewell Night
# **Option A – Nikko** (2‑hour train) – UNESCO shrines, nature, and a chance to see **Edo‑period architecture**.
# **Option B – Yokohama** – **Cup Noodles Museum**, **Ramen Museum**, and a stroll through **Minato Mirai** (future‑city vibe).
# **Evening (back in Tokyo)** – **Shinjuku** or **Roppongi** for a final feast:
# *   **Sukiyabashi Jiro** (if you can snag a reservation) or **Izakaya** “Uoshin Nogizaka” for fresh sashimi.
# *   End with a nightcap at a **sky‑bar** – **The Prince Gallery Tokyo’s** “Sky Lounge Stellar” for a panoramic farewell view.
#
# ---
#
# ## 3️⃣ DEEP‑DIVE: TECH EXPERIENCES YOU CAN’T MISS
#
# | Experience | Where | Why It’s Cool |
# |------------|-------|---------------|
# | **teamLab Borderless/Planets** | Odaiba | Immersive, interactive digital art that reacts to your movement. |
# | **Miraikan** | Odaiba | Hands‑on robotics, AI demos, and a “Future City” model. |
# | **Akihabara’s 2‑koma (2‑floor) arcades** | Akihabara | Classic “Space Invaders” to the latest rhythm games (e.g., **Beatmania**). |
# | **VR & AR arcades** | Shinjuku, Shibuya | Full‑body motion capture rooms (e.g., **VR Zone Shinjuku**). |
# | **Robot Restaurant** | Shinjuku | Neon‑lit cabaret with giant robots, lasers, and techno beats. |
# | **Gadget “Pop‑up” stores** | Harajuku, Shibuya | Limited‑edition collaborations (e.g., **UNIQLO + Google**). |
# | **Smart‑home demo rooms** | **Bic Camera** (Shinjuku) | Try IoT appliances, 8K TVs, and AI assistants. |
#
# **Pro tip:** Many of these places accept **Apple Pay** and **Google Pay**; bring a backup cash envelope for smaller stalls.
#
# ---
#
# ## 4️⃣ CULTURAL HIGH‑POINTS (Beyond the Tourist “Must‑Sees”)
#
# | Spot | What to Do | Insider Tip |
# |------|------------|-------------|
# | **Edo‑Tokyo Museum** | Walk through a life‑size replica of a 17th‑century street. | Grab the free audio guide (Japanese/English). |
# | **Tsukiji Outer Market** | Sushi‑making class, sample tamago (sweet omelet). | Go early (7‑9 am) for the freshest fish. |
# | **Kagurazaka** | Old geisha‑district turned boutique lane. | Stop at **Kagurazaka Saryo** for matcha in a historic tea house. |
# | **Yanaka Ginza** | “Old Tokyo” vibe, narrow lanes, traditional sweets. | Try **kibi dango** (millet dumplings). |
# | **Ghibli Museum** (Mitaka) | Animation art, exclusive short film. | Tickets must be bought **in advance** (Lawson ticket kiosks). |
# | **Sumo Stable Visit** | Watch morning practice (early morning only). | Book through **Tokyo Sumō Tour**; bring a small donation. |
# | **Traditional Ryokan Stay** (e.g., **Hoshinoya Tokyo**) | Experience tatami rooms, onsen, kaiseki dinner. | Book a “culture package” that includes a tea ceremony. |
#
# ---
#
# ## 5️⃣ NIGHTLIFE PLAYBOOK
#
# | Area | Vibe | Must‑Visit Spots |
# |------|------|-------------------|
# | **Shinjuku – Kabukicho** | Neon, bustling, mix of bars & clubs. | **Bar Benfiddich** (cocktail alchemy), **WARP Shinjuku** (hip hop). |
# | **Golden Gai** | Tiny, intimate bars (2‑4 seats). | **Albatross**, **Bar Darling** – each has a theme. |
# | **Roppongi** | Upscale, expat‑friendly, art‑scene. | **Mori Art Museum Night**, **V2 Tokyo** (luxury club). |
# | **Shibuya** | Youthful, trend‑setting. | **Womb**, **Contact**, **Sound Museum Vision**. |
# | **Daikanyama & Nakameguro** | Chic, boutique bars, river walk. | **Bar Tram** (craft cocktails), **Sometaro** (okonomiyaki after‑hours). |
# | **Odaiba** | Futuristic waterfront parties. | **Odaiba Marine Park** for summer fireworks, **Aqua City** rooftop bar. |
#
# **Late‑night food:**
# * **Tsukemen** (dipping ramen) at **Ramen Jiro** (open till 2 am).
# * **Yakiniku** at **Han no Daidokoro Bettei** (Shibuya) – grill your own meat.
# * **Convenience store “bento”** – surprisingly good after a night out.
#
# ---
#
# ## 6️⃣ PRACTICAL INFO & HACKS
#
# | Topic | Details |
# |-------|---------|
# | **Transport** | Get a **Suica** or **Pasmo** card (¥2,000 deposit). Use it on JR Yamanote, subways, buses, and even vending machines. For intercity trips, consider a **JR Pass** (if you’ll go to Nikko, Hakone, Kyoto). |
# | **Language** | English signage is good in central areas. Download **Google Translate** (offline mode) and the **Japan Official Travel App** for real‑time transit. |
# | **Cash vs Card** | Credit cards work in most department stores, chain restaurants, and hotels. Small eateries, street stalls, and temples often require cash. ATMs that accept foreign cards: **7‑Eleven**, **Lawson**, **Japan Post**. |
# | **Wi‑Fi** | Free public Wi‑Fi at most stations (JR East “Free Wi‑Fi”). Consider renting a pocket Wi‑Fi (≈¥800/day) or a local SIM (e.g., **b-mobile**). |
# | **Etiquette** | No loud talking on trains, no eating while walking in most neighborhoods, and always remove shoes when entering traditional inns/temples. |
# | **Best Time to Visit** | **Spring (Mar‑May)** – cherry blossoms, mild weather. **Autumn (Oct‑Nov)** – vibrant foliage, comfortable temps. Avoid Golden Week (late Apr‑early May) if you dislike crowds. |
# | **Safety** | Tokyo is one of the safest major cities. Keep an eye on your belongings in crowded stations, but overall you can walk around late at night without worry. |
# | **Apps** | **HyperDia** (train schedules), **Navitime** (multimodal routing), **GuruNavi** (restaurant search), **Time Out Tokyo** (event listings). |
#
# ---
#
# ## 7️⃣ CUSTOMIZING YOUR TRIP
#
# | Preference | Suggested Add‑Ons |
# |------------|-------------------|
# | **More Tech** | **Odaiba’s “Future Mall”** (Miraikan’s sister space), **Sony ExploraScience** (Shibuya), **Nintendo Tokyo Store** (Shibuya Parco). |
# | **More Culture** | **Kamakura day‑trip** (Great Buddha, Zen temples), **Nikko** (Toshogu Shrine), **Kawagoe** (“Little Edo”). |
# | **More Nightlife** | **Club Ageha** (Shinagawa, massive dance floor), **Womb’s “All‑Night” events**, **Jazz clubs** in **Shinjuku Pit Inn**. |
# | **Foodie Focus** | **Tsukiji Sushi Breakfast**, **Ramen Street** (Tokyo Station), **Izakaya hopping** in **Ebisu Yokocho**, **Michelin‑star sushi** at **Sukiyabashi Jiro** (reservation months ahead). |
# | **Family‑Friendly** | **Ueno Zoo**, **Sunshine City’s “Pokemon Center Mega Tokyo”**, **Tokyo Disneyland/DisneySea** (full day). |
# | **Budget‑Conscious** | Use **JR East Pass (Tokyo area)**, stay in **business hotels** (e.g., **APA**, **Toyoko Inn**), eat at **standing sushi bars** and **conveyor‑belt ramen**. |
#
# ---
#
# ## 8️⃣ QUICK‑START CHECKLIST
#
# 1. **Book flights & accommodation** – stay central (Shinjuku, Shibuya, or Ginza) for easy transit.
# 2. **Reserve tickets** – teamLab, Ghibli Museum, Robot Restaurant, any special dining (Jiro, Sukiyabashi).
# 3. **Get a Suica/Pasmo** – can be ordered online for airport pickup.
# 4. **Download essential apps** – HyperDia, Google Maps, Japan Travel, pocket Wi‑Fi rental.
# 5. **Pack** – comfortable walking shoes, a portable charger, a small umbrella (rain is common).
# 6. **Currency** – exchange a small amount before arrival; ATMs in 7‑Eleven are reliable.
#
# ---
#
# ## 9️⃣ FINAL WORD
#
# Tokyo rewards curiosity. By **morning** you can be sipping matcha in a centuries‑old shrine, **afternoon** you’re battling virtual monsters in a neon arcade, and **night** you’re dancing under a cascade of LED lights in a club that feels like a spaceship. Follow the itinerary above, sprinkle in your own spontaneous detours, and you’ll get a perfect blend of **technology, culture, and nightlife**—the three pillars that make Tokyo unforgettable.
#
# **Enjoy your trip, and feel free to ask if you need deeper details on any specific day, restaurant reservations, or hidden‑gem recommendations!** 🚀🗼🍣
