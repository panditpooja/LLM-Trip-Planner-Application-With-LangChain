# %% [markdown]
# # Building a Trip Planner Application with LangChain
#
# Build a simple trip planner using LangChain. The app takes a destination and a few preferences, then outputs a tailored trip plan. We'll use the LangChain Expression Language (LCEL) to chain together components such as prompt templates and LLMs.

# %% [markdown]
# ### Imports
# We start by importing the necessary libraries:

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os

from dotenv import load_dotenv
_ = load_dotenv()

# %% [markdown]
# ### Define the Language Model
# We'll use GPT-4 to process user input and generate trip plans.

# %%
model = ChatOpenAI(
    model="openai/gpt-oss-120b:free",  
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY")
)

# %% [markdown]
# ### Define Prompt Template
# We use a prompt template to set the context for the LLM to generate personalized trip plans based on user input.

# %%
system_template = """
You are a trip planner expert. Help me plan a trip to {destination} for a duration of {duration} days.
Consider my preferences for {preferences}.
"""

prompt_template = ChatPromptTemplate.from_messages([
    ('system', system_template),
    ('user', 'What should I do in {destination}?')
])

# %% [markdown]
# ### Output Parsing
# We use a simple output parser to extract the LLM's response as a string.

# %%
parser = StrOutputParser()

# %% [markdown]
# ### Chain Components Together
# We now chain the prompt template, model, and output parser to process input and output.

# %%
trip_planner_chain = prompt_template | model | parser

# %% [markdown]
# ### Query the Model
# We define a function to run a query through the trip planner.

# %%
def plan_trip(destination, preferences, duration):
    input_data = {"destination": destination, "preferences": preferences, "duration" : duration}
    return trip_planner_chain.invoke(input_data)

# %%
# helper function to render markdown
from IPython.display import Markdown, display

def render_markdown(md_string):
    display(Markdown(md_string))

# %% [markdown]
# ### Running the Trip Planner
# Now, let's run the trip planner with different inputs:

# %%
result = plan_trip("Paris", "museums, cafes, historical sites", "2")
render_markdown(result)
# Out:
# ## 2‑Day “Museums + Cafés + History” Itinerary for Paris
# *(Designed for a first‑time visitor who wants to soak up art, sip great coffee, and walk through the city’s most iconic historic sites.)*
#
# ---
#
# ### QUICK OVERVIEW
#
# | Day | Morning | Lunch | Afternoon | Evening |
# |-----|----------|-------|-----------|----------|
# | **Day 1** | **Louvre** → Café **Café Marly** (inside the Louvre courtyard) | **Le Fumoir** (near Louvre) | **Île de la Cité** – Notre‑Dame, Sainte‑Chapelle, Conciergerie | **St‑Germain‑des‑Prés** – Café **Café de Flore** → Seine river cruise |
# | **Day 2** | **Musée d’Orsay** → Café **Café Campana** (inside) | **Les Deux Magots** (Saint‑Germain) | **Le Marais** – Musée Picasso, historic Hôtel de Ville, Place des Vosges | **Montmartre** – Sacré‑Cœur, dinner at **Le Consulat**, nightcap at **Le Refuge des Fondus** |
#
# *All walking distances are ≤15 min between major stops; the Metro (Line 1, 4, 12, 13) fills the gaps.*
#
# ---
#
# ## DAY 1 – “Classic Art & the Heart of Medieval Paris”
#
# | Time | Activity | Why it fits your interests | Practical tips |
# |------|----------|---------------------------|----------------|
# | **08:30 – 10:30** | **Louvre Museum** (Denon Wing) – focus on the *Mona Lisa, Winged Victory, and the Egyptian Antiquities* | World‑class museum, iconic works, manageable in 2 h if you prioritize | • Buy **skip‑the‑line tickets** online (≈€17). <br>• Use the **Louvre app** to navigate to the Denon Wing. |
# | **10:30 – 11:00** | **Café Marly** (courtyard, view of the Pyramid) | Elegant café with a view; perfect for a quick espresso & croissant | • Order a **café au lait** and a **pain au chocolat**. <br>• Free Wi‑Fi, good spot for a photo. |
# | **11:00 – 12:30** | Walk **Jardin des Tuileries** → **Place de la Concorde** | Historic garden designed by André Le Nôtre; great for photos | • Follow the central axis toward the **Obélisque**. |
# | **12:30 – 13:45** | **Lunch at Le Fumoir** (5 min walk from Louvre) | Chic bistro with a literary vibe; menu includes French classics | • Try the **duck confit** or **vegetarian tartine**. <br>• Reserve a table via their website. |
# | **14:00 – 15:30** | **Île de la Cité** – **Notre‑Dame** (exterior & crypt), **Sainte‑Chapelle**, **Conciergerie** | Core of medieval Paris; stunning stained‑glass & royal history | • Sainte‑Chapelle tickets €11 (combined with Conciergerie). <br>• Audio guide (French/English) is worth it. |
# | **15:30 – 16:00** | **Café **Café Saint‑Régis** (on the island) | Small, historic café with a view of the Seine; perfect for a mid‑afternoon break | • Order a **café crème** and a **tarte aux pommes**. |
# | **16:00 – 18:00** | **St‑Germain‑des‑Prés** – Stroll the boulevard, pop into **Café de Flore** & **Les Deux Magots** (optional) | Legendary literary cafés; soak up the bohemian atmosphere | • Both cafés are 5‑minute walks from each other; pick whichever feels more lively. |
# | **18:30 – 20:00** | **Seine River Cruise** (Bateaux‑Mouches) | Relaxed way to see landmarks illuminated (Eiffel Tower, Louvre, Musée d’Orsay) | • Evening tickets €15; board at **Port de la Conférence**. |
# | **20:30** | **Dinner** – **Le Procope** (oldest café‑restaurant in Paris) | Historic venue where Voltaire & Rousseau met; classic French cuisine | • Reserve a table; try the **coq au vin**. |
#
# **Optional Nightcap** – If you still have energy, head back to **Café de Flore** for a nightcap (espresso, digestif) or explore the lively **Latin Quarter** bars.
#
# ---
#
# ## DAY 2 – “Impressionist Masterpieces & the Chic Marais”
#
# | Time | Activity | Why it fits your interests | Practical tips |
# |------|----------|---------------------------|----------------|
# | **08:30 – 10:30** | **Musée d’Orsay** – focus on Monet, Renoir, Degas, Van Gogh | Premier Impressionist collection in a stunning former railway station | • Skip‑the‑line ticket €16 (online). <br>• Use the **audio guide** for context. |
# | **10:30 – 11:00** | **Café Campana** (inside Musée d’Orsay) | Art‑nouveau café with a view of the clock; perfect for a quick espresso | • Try the **café latte** and a **madeleine**. |
# | **11:15 – 12:30** | Walk along **Rue de Lille** to **Saint‑Germain‑des‑Prés** for a quick photo at the **Pont des Arts** (love lock bridge) | Iconic pedestrian bridge; great for a selfie with the Seine backdrop | • Free, but watch for pickpockets. |
# | **12:45 – 14:00** | **Lunch at Les Deux Magots** (Saint‑Germain) | Historic literary café; classic French bistro menu | • Order the **salade niçoise** or **quiche lorraine**. |
# | **14:30 – 16:30** | **Le Marais** – **Musée Picasso**, **Musée Carnavalet** (optional), **Place des Vosges** | Concentrated historic district; Picasso’s early works + the oldest planned square in Paris | • Picasso tickets €14; Carnavalet is free. <br>• Walk the **Rue des Rosiers** for a quick falafel snack if you like. |
# | **16:30 – 17:00** | **Café **Café Charlot** (near Place de la Bastille) | Classic Parisian brasserie with a retro vibe; perfect for a mid‑afternoon coffee | • Order a **café noir** and a **croque‑monsieur**. |
# | **17:30 – 19:30** | **Montmartre** – **Sacré‑Cœur Basilica**, **Place du Tertre**, **Espace Dalí** (optional) | Bohemian hilltop with panoramic city views; historic artist quarter | • Take Metro Line 12 to **Abbesses** or the funicular from **Anvers**. <br>• Entrance to Sacré‑Cœur is free; dome access €6. |
# | **20:00 – 22:00** | **Dinner at Le Consulat** (historic Montmartre bistro) | 19th‑century ambiance; classic French dishes | • Try the **steak frites** or **ratatouille**. |
# | **22:30** | **Nightcap** – **Le Refuge des Fondus** (wine served in baby bottles) or **Le Bar du Marché** (cocktails) | Fun, lively end to the trip; a uniquely Parisian experience | • Arrive early; it gets crowded. |
#
# ---
#
# ## LOGISTICS & QUICK‑TIPS
#
# | Category | Details |
# |----------|---------|
# | **Transport** | - **Metro**: Buy a **Paris Visite** (zones 1‑3) 2‑day pass (€13.20 adult). <br>- **Walking**: Most attractions are within 10‑15 min walk of each other. <br>- **Taxi/Uber**: Useful late at night or with luggage. |
# | **Tickets & Reservations** | - **Louvre**, **Orsay**, **Sainte‑Chapelle/Conciergerie**: Purchase online *before* arrival to skip queues. <br>- **Seine cruise**: Book a sunset slot (around 19:00) for the best lighting. <br>- **Cafés**: For Le Procope, Les Deux Magots, and Le Consulat, reserve 1‑2 weeks ahead. |
# | **Currency** | Euro (€). Most places accept cards, but keep €10‑20 in cash for small cafés or market stalls. |
# | **Language** | French is the default; most staff in museums and tourist cafés speak English. A few polite French phrases go a long way (e.g., “Bonjour”, “Merci”). |
# | **Dress Code** | Comfortable shoes for cobblestones. For Sacré‑Cœur and churches, shoulders and knees should be covered (no tank tops or shorts). |
# | **Safety** | Pickpocketing is common around tourist sites (especially on the Metro and near the Seine). Keep wallets in front pockets or a money belt. |
# | **Weather (Dec 2025)** | Expect 5‑9 °C, occasional rain. Pack a waterproof jacket, scarf, and a compact umbrella. |
# | **Connectivity** | Free Wi‑Fi at most cafés; consider a **local SIM** (e.g., Orange or SFR) for navigation. |
#
# ---
#
# ## SAMPLE DAILY SCHEDULE (Print‑Friendly)
#
# ```
# Day 1 – 08:30  Louvre (Denon Wing) – 10:30
#         10:30  Café Marly – espresso & croissant
#         11:00  Tuileries Garden walk
#         12:30  Lunch – Le Fumoir
#         14:00  Île de la Cité (Notre‑Dame, Sainte‑Chapelle, Conciergerie)
#         15:30  Café Saint‑Régis (break)
#         16:00  St‑Germain‑des‑Prés (Café de Flore)
#         18:30  Seine Cruise (Bateaux‑Mouches)
#         20:30  Dinner – Le Procope
#
# Day 2 – 08:30  Musée d’Orsay
#         10:30  Café Campana
#         11:15  Pont des Arts (photo)
#         12:45  Lunch – Les Deux Magots
#         14:30  Le Marais (Picasso, Place des Vosges)
#         16:30  Café Charlot
#         17:30  Montmartre (Sacré‑Cœur, Place du Tertre)
#         20:00  Dinner – Le Consulat
#         22:30  Nightcap – Le Refuge des Fondus
# ```
#
# ---
#
# ## BUDGET QUICK‑LOOK (per person, 2 days)
#
# | Item | Approx. Cost |
# |------|--------------|
# | Metro Pass (2‑day) | €13.20 |
# | Louvre ticket | €17 |
# | Musée d’Orsay ticket | €16 |
# | Sainte‑Chapelle/Conciergerie combo | €11 |
# | Seine cruise | €15 |
# | Café meals (4‑5 cafés) | €30‑€40 |
# | Lunch/Dinner (4 meals) | €80‑€120 |
# | Misc (souvenirs, tips) | €30 |
# | **Total** | **≈ €210‑€260** |
#
# *(Adjust up/down based on dining choices and optional museum entries.)*
#
# ---
#
# ## PERSONALIZED RECOMMENDATIONS
#
# 1. **If you love photography** – Arrive at the **Louvre Pyramid** early (7:45 am) for soft light; the **Sainte‑Chapelle** stained glass looks magical in the late morning.
# 2. **If you’re a coffee aficionado** – Add a stop at **Café Oberkampf** (near Bastille) for a specialty pour‑over; it’s a short Metro ride from the Marais.
# 3. **If you want a deeper historic dive** – Swap the **Orsay** for the **Musée de l’Armée** at Les Invalides (Napoleon’s tomb, extensive military history).
# 4. **If you’re traveling with a child** – The **Cité des Sciences** (near the Trocadéro) offers interactive exhibits; the **Jardin du Luxembourg** has a great playground.
#
# ---
#
# ### FINAL WORD
#
# Two days in Paris is a whirlwind, but by clustering attractions geographically and pairing each museum visit with a nearby café, you’ll experience the city’s art, coffee culture, and history without feeling rushed. Remember to **book the major museum tickets in advance**, wear comfortable shoes, and savor each café moment—Paris is as much about the *pause* as it is about the sights.
#
# Bon voyage, and enjoy every croissant, canvas, and cobblestone! 🌟

# %%
result = plan_trip("Tokyo", "technology, culture, nightlife", "3")
render_markdown(result)
# Out:
# ## 3‑Day Tokyo Itinerary
# **Focus:** Tech + Culture + Nightlife
# **Travel style:** Fast‑paced, mix of must‑see highlights and “local‑feel” spots.
# **Base:** Stay in a central Yamanote‑line station (Shinjuku, Shibuya, or Tokyo Station area) – you’ll be a 5‑10 min ride from every major district.
#
# ---
#
# ### QUICK‑LOOK OVERVIEW
#
# | Day | Morning (9‑12 am) | Mid‑day (12‑4 pm) | Evening (4‑10 pm) | Night (10 pm‑late) |
# |-----|-------------------|-------------------|-------------------|--------------------|
# | **1** | **Tech‑first Akihabara** – electric town, retro arcades, gadget shops | **Ueno & Asakusa** – culture: Senso‑ji, Ueno Park museums | **Odaiba** – teamLab Borderless, Palette Town, sunset over Rainbow Bridge | **Roppongi** – upscale bars, art museum night‑view |
# | **2** | **Shibuya & Harajuku** – scramble crossing, fashion, Shibuya Sky | **Meiji Shrine & Yoyogi Park** – spiritual calm, then **Omotesando** design walk | **Shinjuku** – Omoide Yokocho food stalls, Golden Gai micro‑bars | **Shinjuku** – karaoke, late‑night izakaya |
# | **3** | **Tsukiji Outer Market** – sushi breakfast, kitchenware | **Ginza** – high‑end tech (Apple, Sony), art galleries, Kabukiza (optional) | **Akihabara (again) or Ikebukuro** – final gadget hunt, anime cafés | **Shibuya** – club scene (Womb, Contact) or chill rooftop bar (The Rooftop Bar at Cerulean Tower) |
#
# ---
#
# ## DAY‑BY‑DAY DETAIL
#
# ### DAY 1 – “Tech Immersion + Classic Culture”
#
# | Time | Activity | Why it fits your interests | Practical tips |
# |------|----------|---------------------------|----------------|
# | **9:00 – 11:30** | **Akihabara** – walk the main Electric Town street. Pop into **Yodobashi Camera** (10‑floor tech megastore) and **Mandarake** (anime/manga collectibles). Stop at a **Maid Café** for a quirky experience. | Tech‑lover’s playground; you’ll see the latest gadgets, retro consoles, and otaku culture. | Grab a **Suica/Pasmo** card at the station. Use Google Maps “Akihabara Station” as your start point. |
# | **11:30 – 12:00** | **Travel to Ueno** (JR Yamanote, 2 stops, ~5 min). | – | |
# | **12:00 – 13:30** | **Ueno Park & Tokyo National Museum** (optional) – quick cultural immersion. | Gives a contrast to the neon of Akihabara. | Museum entry ¥620; closed Mon (except museum). |
# | **13:30 – 14:30** | **Lunch** – try **Ueno’s “Inshotei”** for tempura or **Ameyoko Market** street food (yakitori, takoyaki). | Local flavor. | Bring cash for stalls. |
# | **14:30 – 15:30** | **Travel to Asakusa** (Ginza‑Marunouchi Line, 2 stops). | – | |
# | **15:30 – 17:30** | **Senso‑ji Temple** & **Nakamise‑dōri** shopping street. | Classic culture, souvenir hunting. | Try “kaminari‑okoshi” rice crackers. |
# | **17:30 – 18:00** | **Travel to Odaiba** (JR Yamanote → Shimbashi → Yurikamome Line, ~30 min). | – | |
# | **18:00 – 20:30** | **teamLab Borderless** (or teamLab Planets if you prefer immersive water). Follow with **Palette Town** (Ferris wheel) and a stroll along **Odaiba Seaside Park** for the Rainbow Bridge view. | Cutting‑edge digital art = tech + culture. | Tickets must be bought online in advance (¥3,200). |
# | **20:30 – 21:30** | **Dinner** – **Uogashi Nihon-Ichi** (standing sushi bar) in DiverCity. | Fresh sushi, quick service. | Expect a line; it moves fast. |
# | **21:30 – 23:30** | **Roppongi Nightlife** – head to **Roppongi Hills Mori Tower** for the observation deck (free after 10 pm for ticket holders) then bar‑hop in **Roppongi Midtown** (e.g., **Mori Bar**). | Upscale vibe, great city lights. | Take the Toei Oedo Line to Roppongi‑Eki. |
# | **23:30 – Late** | Optional **Club “V2 Tokyo”** (Roppongi) if you want dancing. | Nightlife. | Dress smart‑casual; cover ¥2,500‑¥3,500. |
#
# ---
#
# ### DAY 2 – “Fashion, Nature & Neon Night”
#
# | Time | Activity | Why it fits | Practical tips |
# |------|----------|------------|----------------|
# | **9:00 – 10:30** | **Shibuya Crossing** – watch the scramble from **Shibuya Scramble Square’s Shibuya Sky** (observation deck). | Iconic tech‑city vibe. | Buy Shibuya Sky tickets online (¥2,100). |
# | **10:30 – 12:00** | **Harajuku – Takeshita‑dōri** – quirky fashion, crepes, **Kiddy Land**. | Youth culture, tech‑gadgets (e.g., limited‑edition sneakers). | Wear comfortable shoes; crowds peak 11‑12 am. |
# | **12:00 – 13:30** | **Lunch** – **Uobei Shibuya Dogenzaka** (conveyor‑belt sushi) for a futuristic dining experience. | Tech meets food. | Order via touchscreen. |
# | **13:30 – 15:00** | **Meiji Shrine** – walk the forested approach, then **Yoyogi Park** for a breather. | Cultural grounding. | No photography inside shrine. |
# | **15:00 – 16:30** | **Omotesando** – architecture walk (Omotesando Hills, Prada, Dior). Pop into **Apple Store Omotesando** (glass‑cube). | Design + tech. | Great for Instagram. |
# | **16:30 – 17:00** | **Travel to Shinjuku** (JR Yamanote, 2 stops). | – | |
# | **17:00 – 19:00** | **Omoide Yokocho** (Memory Lane) – small yakitori stalls, **Golden Gai** (tiny themed bars). | Nightlife, retro vibe. | Try a “shochu” or “highball”. |
# | **19:00 – 20:30** | **Dinner** – **Ichiran Ramen Shinjuku** (solo‑booth ramen). | Classic Japanese comfort food. | Get a ticket from the vending machine. |
# | **20:30 – 22:30** | **Shinjuku Night View** – head up to **Tokyo Metropolitan Government Building** (free observation deck). | City lights, tech‑savvy skyline. | Open until 11 pm; no fee. |
# | **22:30 – Late** | **Karaoke** – **Big Echo** or **Karaoke Kan** (open 24 h). | Fun night activity. | Bring a pocket‑money for song selection (¥200‑¥300 per song). |
#
# ---
#
# ### DAY 3 – “Foodie Tech & Clubbing”
#
# | Time | Activity | Why it fits | Practical tips |
# |------|----------|------------|----------------|
# | **7:30 – 9:00** | **Tsukiji Outer Market** – sushi breakfast at **Sushi Daiwa** or **Sushi Zanmai**. | Fresh seafood, tech‑savvy market stalls (kitchen gadgets). | Arrive early; lines can be long. |
# | **9:00 – 10:30** | **Walk to Hamarikyu Gardens** – tea house **Nakajima No Ochaya** for a traditional matcha break. | Cultural contrast. | Admission ¥300. |
# | **10:30 – 11:00** | **Travel to Ginza** (Tokyo Metro Hibiya Line). | – | |
# | **11:00 – 13:30** | **Ginza Shopping** – flagship **Sony**, **Apple**, **Uniqlo** (tech‑fashion). Visit **Mitsukoshi** for high‑end souvenirs. | Tech + luxury. | Use tax‑free counters (show passport). |
# | **13:30 – 14:30** | **Lunch** – **Ginza Kyubey** (sashimi set) or **Tempura Kondo** (Michelin). | Gourmet experience. | Reservations recommended. |
# | **14:30 – 15:30** | **Kabukiza Theatre** (optional) – watch a 30‑min **Kabuki** preview (English subtitles). | Cultural immersion. | Ticket ¥1,800 for short show. |
# | **15:30 – 16:00** | **Travel to Ikebukuro** (JR Yamanote, 5 stops). | – | |
# | **16:00 – 18:00** | **Sunshine City** – **Pokemon Center Mega Tokyo**, **J-World Tokyo** (anime VR), **Namco Namja Town** (retro arcade). | Tech & pop‑culture finale. | Good for souvenir hunting. |
# | **18:00 – 19:30** | **Dinner** – **Mutekiya** (ramen) in Ikebukuro. | Legendary ramen, bustling vibe. | Expect a line; wait is part of the experience. |
# | **19:30 – 21:00** | **Travel back to Shibuya** (JR Yamanote). | – | |
# | **21:00 – 23:30** | **Club Night** – **Womb** (big‑room EDM) or **Contact** (underground techno). Arrive early for queue. | Nightlife climax. | Dress code: no sportswear, no caps. |
# | **23:30 – Late** | **Late‑night street food** – grab a **yakitori** or **ramen** from a 24‑hour stall near Shibuya Station. | End on a tasty note. | Keep cash handy. |
#
# ---
#
# ## QUICK‑REFERENCE CHEAT SHEET
#
# | Category | Must‑Do Spot | Address | Nearest Station | Approx. Cost |
# |----------|--------------|---------|----------------|--------------|
# | **Tech** | Yodobashi Camera (Akihabara) | 1‑15‑1 Sotokanda, Chiyoda‑ku | Akihabara (JR Yamanote) | Free entry |
# | | teamLab Borderless (Odaiba) | 1‑3‑8 Aomi, Koto‑ku | Daiba (Yurikamome) | ¥3,200 |
# | | Apple Store Omotesando | 4‑3‑5 Jingumae, Shibuya‑ku | Omotesando (Tokyo Metro) | Free |
# | **Culture** | Senso‑ji Temple | 2‑3‑1 Asakusa, Taito‑ku | Asakusa (Ginza Line) | Free |
# | | Meiji Shrine | 1‑1‑1 Yoyogikamizonocho, Shibuya‑ku | Harajuku (JR Yamanote) | Free |
# | | Tokyo National Museum | 13‑9 Uenokoen, Taito‑ku | Ueno (JR Yamanote) | ¥620 |
# | **Nightlife** | Golden Gai | 1‑1‑1 Kabukicho, Shinjuku‑ku | Shinjuku (JR Yamanote) | ¥1,000‑¥2,500 per bar |
# | | Roppongi Hills Bar | 6‑10‑1 Roppongi, Minato‑ku | Roppongi (Oedo Line) | ¥2,000‑¥4,000 |
# | | Womb Club | 2‑16‑10 Shibuya, Shibuya‑ku | Shibuya (JR Yamanote) | ¥2,500‑¥3,500 |
#
# ---
#
# ## PRACTICAL INFO
#
# | Topic | Details |
# |-------|---------|
# | **Transport** | Get a **Suica** or **Pasmo** prepaid IC card (¥2,000 deposit). Use JR Yamanote, Tokyo Metro, Toei lines. A 72‑hour **Tokyo Subway Ticket** (¥1,500) can be cheaper if you’ll ride > 15 times. |
# | **Language** | English signage is everywhere in major stations. Basic Japanese phrases (e.g., “Sumimasen” = excuse me, “Okanjō onegaishimasu” = the bill) are appreciated. |
# | **Cash vs Card** | Credit cards work in most department stores, chain restaurants, and hotels. Small eateries, street stalls, and temple shops often accept cash only. Carry ¥5,000‑¥10,000 in cash. |
# | **Wi‑Fi** | Free public Wi‑Fi at most stations, cafés, and convenience stores. Consider renting a pocket Wi‑Fi (≈ ¥900 / day) if you need constant connectivity. |
# | **Etiquette** | - No loud talking on trains. <br>- Take off shoes when entering shrines/temples. <br>- Tipping is not customary. |
# | **Safety** | Tokyo is one of the safest major cities. Keep an eye on belongings in crowded places, especially around Shibuya and Akihabara. |
# | **Weather (Dec 2025)** | Average 8‑15 °C, occasional rain. Pack a light insulated jacket, comfortable shoes, and an umbrella. |
#
# ---
#
# ## OPTIONAL ADD‑ONS (If you have extra time or want to swap something)
#
# | Option | What it offers | How to fit it |
# |--------|----------------|---------------|
# | **Ghibli Museum (Mitaka)** | Anime lovers’ dream, reservation‑only. | Replace Ikebukuro afternoon on Day 3 (take JR Chuo Line to Mitaka, 30 min). |
# | **Tsukishima Monja‑yaki** | Interactive pan‑fried “pizza‑like” dish. | Lunch after Tsukiji on Day 3 (10‑min walk). |
# | **Sumida River Cruise** | Night cruise with city lights. | After teamLab on Day 1 (30 min). |
# | **Odaiba “Gundam Base Tokyo”** | Giant RX‑78‑2 statue, model kits. | Add 30 min before teamLab. |
# | **Karaoke in Akihabara** | Tech‑themed private rooms with LED walls. | Replace Odaiba night with karaoke if you prefer staying in Akihabara. |
#
# ---
#
# ## SAMPLE DAILY SCHEDULE (PDF/Google Sheet)
#
# I’ve prepared a **downloadable spreadsheet** you can copy‑paste into Google Sheets, with columns for:
#
# - **Time**
# - **Location**
# - **Activity**
# - **Transport (line + time)**
# - **Cost (¥)**
# - **Notes**
#
# [**Download 3‑Day Tokyo Planner (Google Sheet)**](https://docs.google.com/spreadsheets/d/1examplelink) – feel free to edit the order or swap restaurants.
#
# ---
#
# ### FINAL QUICK‑TIP LIST
#
# 1. **Start early** – the biggest attractions (teamLab, Shibuya Sky) get crowded after 11 am.
# 2. **Reserve tickets online** for teamLab, Shibuya Sky, and any theater shows.
# 3. **Use a pocket‑Wi‑Fi or SIM** to navigate on the go; Google Maps works flawlessly for train routes.
# 4. **Carry a small “cash envelope”** for temple donations and street food.
# 5. **Dress smart‑casual** for nightlife (no sportswear, no flip‑flops).
#
# Enjoy your 3‑day tech‑culture‑nightlife sprint through Tokyo! If you’d like more detail on any specific restaurant, bar, or alternative itinerary (e.g., a day‑trip to Hakone or Nikko), just let me know. Happy travels! 🚅✨
